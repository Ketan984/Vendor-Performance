# %%
import pandas as pd
import os 
from sqlalchemy import create_engine
import time
import logging 
os.makedirs("logs", exist_ok=True)

logging.basicConfig(
    filename="logs/ingestion_db.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a",
    force=True
)

# %%
engine = create_engine(
    "mysql+pymysql://root:Ketan201812@localhost/inventory_db",
    pool_pre_ping=True,
    isolation_level="AUTOCOMMIT"
)

# %%
def ingest_db(file_path, table_name, engine):
    first_chunk = True
    chunk_number = 1

    for chunk in pd.read_csv(file_path, chunksize=5000):
        chunk.to_sql(
            table_name,
            con=engine,
            if_exists='replace' if first_chunk else 'append',
            index=False
        )

        print(f"{table_name} - Inserted chunk {chunk_number}")
        chunk_number += 1
        first_chunk = False

def load_raw_data():
    for file in os.listdir('data'):
        if file.endswith('.csv'):
            print(f"Ingesting {file}")
            ingest_db(
                os.path.join('data', file),
                file[:-4],
                engine
            )
 
    end = time.time()
    total_time=(end - start)/60
    logging.info('----------Ingestion Complete---------')
    logging.info(f'\nTotal time Taken:{total_time} minutes')
if __name__ == "__main__":
    load_raw_data()
# Out:
# Ingesting begin_inventory.csv
# begin_inventory - Inserted chunk 1
# begin_inventory - Inserted chunk 2
# begin_inventory - Inserted chunk 3
# begin_inventory - Inserted chunk 4
# begin_inventory - Inserted chunk 5
# begin_inventory - Inserted chunk 6
# begin_inventory - Inserted chunk 7
# begin_inventory - Inserted chunk 8
# begin_inventory - Inserted chunk 9
# begin_inventory - Inserted chunk 10
# begin_inventory - Inserted chunk 11
# begin_inventory - Inserted chunk 12
# begin_inventory - Inserted chunk 13
# begin_inventory - Inserted chunk 14
# begin_inventory - Inserted chunk 15
# begin_inventory - Inserted chunk 16
# begin_inventory - Inserted chunk 17
# begin_inventory - Inserted chunk 18
# begin_inventory - Inserted chunk 19
# begin_inventory - Inserted chunk 20
# begin_inventory - Inserted chunk 21
# begin_inventory - Inserted chunk 22
# begin_inventory - Inserted chunk 23
# begin_inventory - Inserted chunk 24
# begin_inventory - Inserted chunk 25
# ...

# %%
logging.info("TEST LOG ENTRY")
